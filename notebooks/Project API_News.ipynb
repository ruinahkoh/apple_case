# %% [markdown]
# #### pip install newsapi-python

# %%
# -*- coding: utf-8 -*-
from datetime import datetime, date, timedelta
# from newspaper import Article
from config import API_KEY, DYNAMODB_ARTICLES_TABLE,BUCKET_NAME
from newsapi  import NewsApiClient
import zipfile
import pandas as pd
# Out:
# /Users/ruinah/Documents/ISYE6740/project/api/myenv/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
def get_key_word(url):
        key_words = []
        article = Article(url)
        article.download()
        # article.html
        article.parse()
        article.nlp()

        return article.text, article.summary
def get_news_articles(topic,date_from, date_to):
    # Init
    newsapi = NewsApiClient(api_key=API_KEY)
    
    # get everything using topic for query key
    articles= newsapi.get_everything(q=topic,language='en',from_param=date_from,
                                      to=date_to)
    print(len(articles['articles']))
    art=[]
    for i in range(len(articles['articles'])):
        title = articles['articles'][i]['title']
        url = articles['articles'][i]['url']
        blurp = articles['articles'][i]['description']
        imgurl = articles['articles'][i]['urlToImage']
        article_date = articles['articles'][i]['publishedAt']
        article_date = article_date.split('T')[0]
        source = articles['articles'][i]['source']['name'].lower()

        try:
            text, blurp1 = get_key_word(url)
        except:
            text = articles['articles'][i]['content']

        try:
            article_date = datetime.strptime(article_date, "%Y-%m-%d")
            article_date = datetime.strftime(article_date, "%d/%m/%Y")
        except IndexError:
            article_date = date.today().replace(day=1)
            article_date = datetime.strftime(article_date, "%d/%m/%Y")
        art.append(
        {
            'title': title,
            'imgurl': imgurl,
            'date': article_date,
            'blurp': blurp,
            'url': url,
            'text': text,
            'category': topic,
            'source': source
        })
    return art

# %%
### set a defined list of topics
# '
topics = ['artificial intelligence', 'cybersecurity', 'blockchain', 'cloud computing','electric vehicles']

# %%
dates =[] 
date_from = '2024-12-01'

for day in [7]:
    date_to = datetime.strptime(date_from, '%Y-%m-%d') + timedelta(days=day)
    dates.append(datetime.strftime(date_to,'%Y-%m-%d'))
dates
# Out:
# ['2024-12-08']

# %%
date_to = '2022-12-18'
# articles2 = get_news_articles('ai',date_from, date_to)

# %%
art = get_news_articles('ai',date_from, date_to)
# Out:
# 100

# %%
len(art)
# Out:
# 100

# %%
len(articles)
# Out:
# 50

# %%
articles =[]
for topic in topics:
    art = get_news_articles(topic,date_from, date_to)
    for a in art:
        articles.append(a)
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
len(articles)
# Out:
# 500

# %%
articles =[]
for topic in topics:
    for d in dates:
        date_to = d
        art = get_news_articles(topic,date_from, date_to)
        for a in art:
            articles.append(a)
        date_from = date_to
# Out:
# {'status': 'ok', 'totalResults': 4232, 'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'}, 'author': 'Todd Feathers', 'title': 'Nobel Prize Goes to ‘Godfathers of AI’ Who Now Fear Their Work Is Growing Too Powerful', 'description': 'John Hopfield and Geoffrey Hinton developed artificial neural networks that laid the foundation for modern recommendation systems and generative AI.', 'url': 'https://gizmodo.com/nobel-prize-goes-to-godfathers-of-ai-who-now-fear-their-work-is-growing-too-powerful-2000509098', 'urlToImage': 'https://gizmodo.com/app/uploads/2024/10/nobel-hinton-hopfield-ai.jpg', 'publishedAt': '2024-10-08T15:40:43Z', 'content': 'Two AI researchers, John Hopfield and Geoffrey Hinton, received the Nobel Prize in physics on Monday for their work building artificial neural networks that can memorize information and recognize pat… [+3174 chars]'}, {'source': {'id': None, 'name': '[Removed]'}, 'author': None, 'title': '[Removed]', 'description': '[Removed]', 'url': 'https://removed.com', 'urlToImage': None, 'publishedAt': '2024-10-08T19:45:32Z', 'content': '[Removed]'}, {'source': {'id': None, 'name': 'The Atlantic'}, 'author': 'Matteo Wong', 'title': 'A Nobel Prize for Artificial Intelligence', 'description': 'The award should not feed the AI-hype cycle.', 'url': 'https://www.theatlantic.com/newsletters/archive/2024/10/of-course-ai-just-got-a-nobel-prize/680197/', 'urlToImage': 'https://cdn.theatlantic.com/thumbor/9KQb2xZMaQH7VIhZhgKJuWEoglU=/0x41:2000x1083/1200x625/media/img/mt/2024/10/nobles_AIntelligence-1/original.jpg', 'publishedAt': '2024-10-08T21:32:00Z', 'content': 'This is Atlantic Intelligence, a newsletter in which our writers help you wrap your mind around artificial intelligence and a new machine age. Sign up here.The list of Nobel laureates reads like a co… [+3668 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Kris Holt', 'title': "Machine learning pioneers, including the 'Godfather of AI,' are awarded the Nobel Prize in Physics", 'description': 'Two scientists have been awarded\r\n the Nobel Prize in Physics “for foundational discoveries and inventions that enable machine learning\r\n with artificial neural networks.” John Hopfield, an emeritus professor of Princeton University, devised an associative me…', 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_6520a371-80be-4f58-afc3-cdc8b7ee93c5', 'urlToImage': None, 'publishedAt': '2024-10-08T13:21:24Z', 'content': "If you click 'Accept all', we and our partners, including 240 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"}, {'source': {'id': None, 'name': 'Gizmodo.com'}, 'author': 'Matt Novak', 'title': 'OpenAI Raises Billions While Pledging to Work With ‘U.S. and Allied Governments’', 'description': "OpenAI is now valued at $157 billion, a close read of OpenAI's statement might provide some hints about the future.", 'url': 'https://gizmodo.com/openai-raises-billions-while-pledging-to-work-with-u-s-and-allied-governments-2000506556', 'urlToImage': 'https://gizmodo.com/app/uploads/2024/10/sam-altman-getty.jpg', 'publishedAt': '2024-10-02T21:50:39Z', 'content': 'OpenAI has raised $6.6 billion at a $157 billion post-money valuation, according to a statement the company posted online Wednesday. The funding round was led by Thrive Capital, which invested $1.25 … [+4379 chars]'}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'Jyoti Mann', 'title': "Geoffrey Hinton, the 'godfather of AI' who warned of its existential risk, awarded Nobel Prize for Physics", 'description': 'Geoffrey Hinton and John J. Hopfield win the 2024 Nobel Prize in Physics for  machine learning inventions with artificial neural networks.', 'url': 'https://www.businessinsider.com/geoffrey-hinton-godfather-ai-nobel-prize-physics-john-hopfield-2024-10', 'urlToImage': 'https://i.insider.com/67050a7a3f ...
# {'status': 'ok', 'totalResults': 267, 'articles': [{'source': {'id': None, 'name': 'Slashdot.org'}, 'author': 'msmash', 'title': 'OpenAI Says China-Linked Group Tried to Phish Its Employees', 'description': 'OpenAI said a group with apparent ties to China tried to carry out a phishing attack on its employees, reigniting concerns that bad actors in Beijing want to steal sensitive information from top US artificial intelligence companies. From a report: The AI star…', 'url': 'https://it.slashdot.org/story/24/10/09/1515226/openai-says-china-linked-group-tried-to-phish-its-employees', 'urlToImage': 'https://a.fsdn.com/sd/topics/security_64.png', 'publishedAt': '2024-10-09T15:20:00Z', 'content': "The AI startup said Wednesday that a suspected China-based group called SweetSpecter posed as a user of OpenAI's chatbot ChatGPT earlier this year and sent customer support emails to staff. The email… [+692 chars]"}, {'source': {'id': None, 'name': 'Techdirt'}, 'author': 'Gretchen Heckmann', 'title': 'Daily Deal: Cybersecurity Projects Bundle', 'description': 'The Cybersecurity Projects Bundle offers a hands-on program featuring five real-world cybersecurity projects, totaling 35 tasks. Participants start with an introductory video for each project, detailing objectives and requirements, followed by task completion…', 'url': 'https://www.techdirt.com/2024/10/09/daily-deal-cybersecurity-projects-bundle-2/', 'urlToImage': 'https://www.techdirt.com/wp-content/themes/techdirt/assets/images/td-rect-logo-white.png', 'publishedAt': '2024-10-09T17:54:46Z', 'content': 'from the good-deals-on-cool-stuff dept\r\nThe Cybersecurity Projects Bundle offers a hands-on program featuring five real-world cybersecurity projects, totaling 35 tasks. Participants start with an int… [+708 chars]'}, {'source': {'id': None, 'name': 'CNET'}, 'author': 'Bree Fowler', 'title': 'Marriott to Boost Data Protection Practices as Part of Deal With FTC', 'description': 'The agreement settles charges stemming from a trio of data breaches that compromised the personal information of more than 344 million customers.', 'url': 'https://www.cnet.com/tech/services-and-software/marriott-to-boost-data-protection-practices-as-part-of-deal-with-ftc/', 'urlToImage': 'https://www.cnet.com/a/img/resize/389497a77ed336f03b800eae8ef6870f3f0d3fa8/hub/2024/10/09/0e63f3eb-4d90-483e-ac01-62f5f30e903b/gettyimages-1679264003.jpg?auto=webp&fit=crop&height=675&width=1200', 'publishedAt': '2024-10-09T18:28:00Z', 'content': 'Marriott International and its Starwood Hotels &amp; Resorts Worldwide subsidiary will put in place a "robust" new data security program to settle charges that its poor security practices led to a tr… [+3009 chars]'}, {'source': {'id': None, 'name': 'Schneier.com'}, 'author': 'Bruce Schneier', 'title': 'IronNet Has Shut Down', 'description': 'After retiring in 2014 from an uncharacteristically long tenure running the NSA (and US CyberCommand), Keith Alexander founded a cybersecurity company called IronNet. At the time, he claimed that it was based on IP he developed on his own time while still in …', 'url': 'https://www.schneier.com/blog/archives/2024/10/ironnet-has-shut-down.html', 'urlToImage': None, 'publishedAt': '2024-10-09T11:56:57Z', 'content': 'After retiring in 2014 from an uncharacteristically long tenure running the NSA (and US CyberCommand), Keith Alexander founded a cybersecurity company called IronNet. At the time, he claimed that it … [+2192 chars]'}, {'source': {'id': 'techradar', 'name': 'TechRadar'}, 'author': 'Ellen Jennings-Trace', 'title': 'Kaspersky is closing its UK office', 'description': 'Russian cybersecurity giant Kaspersky confirms plans to shut UK office.', 'url': 'https://www.techradar.com/pro/kaspersky-is-closing-its-uk-office', 'urlToImage': 'https://cdn.mos.cms.futurecdn.net/7T9KzmEHNpxr8omE5tiHBH-1200-80.jpeg', 'publishedAt': '2024-10-09T10:10:18Z', 'content': 'Just months after cyber security giant Kaspersky closed up shop in the US, the company  ...
# {'status': 'ok', 'totalResults': 125, 'articles': [{'source': {'id': None, 'name': 'Theregister.com'}, 'author': 'Laura Dobberstein', 'title': 'Asian crime gangs are growing – fast – thanks to AI and other tech', 'description': "UN report finds Telegram, cryptocurrency are tools of a growing 'criminal service economy'\nOrganized crime syndicates across Asia are using AI, messaging platforms like Telegram, and cryptocurrency to help them expand, with help from dedicated service provide…", 'url': 'https://www.theregister.com/2024/10/09/the_criminals_are_gaining_efficiencies/', 'urlToImage': 'https://regmedia.co.uk/2023/06/19/shutterstock_asia_abstract_map.jpg', 'publishedAt': '2024-10-09T02:17:06Z', 'content': 'Organized crime syndicates across Asia are using AI, messaging platforms like Telegram, and cryptocurrency to help them expand, with help from dedicated service providers, according to a report the U… [+5599 chars]'}, {'source': {'id': None, 'name': 'CoinDesk'}, 'author': 'Bradley Keoun', 'title': "Protocol Village: Nexus Launches 'World's First Open Prover Network' in Beta", 'description': 'The latest in blockchain tech upgrades, funding announcements and deals. For the period of Oct. 10-16.', 'url': 'https://www.coindesk.com/tech/2024/10/09/protocol-village/', 'urlToImage': 'https://www.coindesk.com/resizer/-K8yQM3cjwQQzIaRSAnWWk7hT3o=/1200x628/center/middle/cloudfront-us-east-1.images.arcpublishing.com/coindesk/TD63KGNZYVBFXGZY7KH7MDAHLY.jpeg', 'publishedAt': '2024-10-09T23:40:23Z', 'content': 'Livepeer, a decentralized video-streaming project, hosted an AI Demo Day, showcasing eight startups that participated in its AI Startup Program over the past three months. According to the team, "The… [+402 chars]'}, {'source': {'id': None, 'name': 'Theregister.com'}, 'author': 'Brandon Vigliarolo', 'title': 'Bitcoin creator suspect says he is not Bitcoin creator suspect', 'description': "'If I was Satoshi I would have destroyed my ability to prove I'm Satoshi'\nThe man identified as Bitcoin creator Satoshi Nakamoto in a new HBO documentary has something to say: Wrong again, world.…", 'url': 'https://www.theregister.com/2024/10/09/satoshi_nakamoto_suspect_hbo_bitcoin/', 'urlToImage': 'https://regmedia.co.uk/2016/06/06/bitcoinsstack.jpg', 'publishedAt': '2024-10-09T17:00:08Z', 'content': "The man identified as Bitcoin creator Satoshi Nakamoto in a new HBO documentary has something to say: Wrong again, world.\r\nIn the just-released HBO film on the history of the world's biggest digital … [+6425 chars]"}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Forbes Membership, Forbes Staff, \n Forbes Membership, Forbes Staff\n https://www.forbes.com/sites/members-only-events/people/forbes-membership/', 'title': 'Members-Only Event: Best Investment Strategies In Stocks, Bonds And Crypto', 'description': 'Join us on Thursday, October 17th at 2PM EST as our panel of investing experts share their business insights and practical investment advice across the finance and crypto landscape to help you gain a nuanced understanding on the future of economics in the wak…', 'url': 'https://www.forbes.com/sites/members-only-events/2024/10/09/members-only-event-best-investment-strategies-in-stocks-bonds-and-crypto/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6706ab9c226fc56bc10518e3/0x0.jpg?format=jpg&crop=1200,675,x0,y0,safe&height=900&width=1600&fit=bounds', 'publishedAt': '2024-10-09T16:35:35Z', 'content': 'Strengthen Your Portfolio To End The Year Strong\r\nJoin us on Thursday, October 17th at 2PM EST as our panel of investing experts share their business insights and practical investment advice across t… [+2540 chars]'}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Sandy Carter, Contributor, \n Sandy Carter, Contributor\n https://www.forbes.com/sites/sandycarter/', 'title': 'Will The Real Satoshi Please Stand Up? Or Does It Matter To Bitcoin?', 'description': 'The Bitcoin Mystery, the new HBO documentary  ...
# {'status': 'ok', 'totalResults': 83, 'articles': [{'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'Eugene Kim', 'title': "Amazon is becoming Big Tech's king of cash, and Wall Street wants a piece of it", 'description': 'The company used to be relatively cash poor compared to Big Tech rivals. Now, the cloud giant is expected to amass almost $400 billion by 2027.', 'url': 'https://www.businessinsider.com/amazon-big-tech-cash-king-wall-street-wants-a-piece-2024-10', 'urlToImage': 'https://i.insider.com/657cd10950edbc52a86501c2?width=1200&format=jpeg', 'publishedAt': '2024-10-09T18:05:13Z', 'content': "Chelsea Jia Feng/BI\r\n<ul><li>Amazon's cash balance is expected to reach almost $400 billion by 2027, far outpacing tech rivals.</li><li>This cash gusher stems from record profits, cost-cutting, and s… [+5639 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Neha Gupta', 'title': 'Microsoft Corp (MSFT): Stock That Will Make You Rich in 5-10 Years', 'description': 'We recently compiled a list of the 10 stocks that will make you rich in 5-10 years. In this article, we are going to take a look at where Microsoft Corp...', 'url': 'https://finance.yahoo.com/news/microsoft-corp-msft-stock-rich-062217055.html', 'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png', 'publishedAt': '2024-10-09T06:22:17Z', 'content': 'We recently compiled a list of the\xa010 stocks that will make you rich in 5-10 years.\xa0In this article, we are going to take a look at where Microsoft Corp (NASDAQ:MSFT) stands against the other the Sto… [+10243 chars]'}, {'source': {'id': None, 'name': 'Slashdot.org'}, 'author': 'BeauHD', 'title': 'Foxconn Building Nvidia Superchip Facility In Mexico', 'description': 'Foxconn has chosen Mexico for the site of the world\'s largest manufacturing facility for Nvidia\'s GB200 superchips. These chips are a "key component of the U.S. firm\'s next-generation Blackwell family computing platform," notes Reuters. From the report: "We\'r…', 'url': 'https://slashdot.org/story/24/10/08/2219214/foxconn-building-nvidia-superchip-facility-in-mexico', 'urlToImage': 'https://a.fsdn.com/sd/topics/business_64.png', 'publishedAt': '2024-10-09T01:25:00Z', 'content': '"We\'re building the largest GB200 production facility on the planet," said Benjamin Ting, Foxconn senior vice president for the cloud enterprise solutions business group. Nvidia said in August that i… [+1031 chars]'}, {'source': {'id': None, 'name': "Investor's Business Daily"}, 'author': "Investor's Business Daily", 'title': 'Seagate Profit Expected To Soar 833% As AI Demand Starts To Bubble', 'description': 'Seagate, the disk drive maker, says demand from AI-related computing is in the "early innings." Seagate stock is in a cup-with-handle base.', 'url': 'https://www.investors.com/research/ibd-stock-analysis/seagate-stock-ai-data-centers/', 'urlToImage': 'https://www.investors.com/wp-content/uploads/2017/10/Stock-seagate-01-company.jpg', 'publishedAt': '2024-10-09T14:01:04Z', 'content': "While much of the buzz around artificial intelligence now focuses on high-performance chips and software, just as important are data centers and massive data storage. That's why Seagate Technology (S… [+3406 chars]"}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Rahul Mewawalla, Forbes Councils Member, \n Rahul Mewawalla, Forbes Councils Member\n https://www.forbes.com/councils/forbestechcouncil/people/rahulmewawalla/', 'title': 'How Data Centers Are Revolutionizing Sustainability In The Age Of AI', 'description': "The revolution in data center sustainability is underway, and it's up to us to lead the charge toward a greener, more sustainable digital economy.", 'url': 'https://www.forbes.com/councils/forbestechcouncil/2024/10/09/how-data-centers-are-revolutionizing-sustainability-in-the-age-of-ai/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/670575d7713c2ef2ac86e767/0x0.jpg?format ...
# {'status': 'ok', 'totalResults': 221, 'articles': [{'source': {'id': None, 'name': 'Harvard Business Review'}, 'author': None, 'title': 'Adapting Electrical Panels to Meet the Future’s More Demanding Loads - SPONSOR CONTENT FROM SCHNEIDER ELECTRIC', 'description': 'Sponsor content from Schneider Electric.', 'url': 'https://hbr.org/sponsored/2024/10/adapting-electrical-panels-to-meet-the-futures-more-demanding-loads', 'urlToImage': 'https://hbr.org/resources/images/article_assets/2024/06/IND24_023_SCH_INNOVATION_SUMMITS_SE_V19.00_16_55_04.Still0143-1.png', 'publishedAt': '2024-10-09T21:09:33Z', 'content': 'Sponsor content from Schneider Electric.\r\n"&gt;\r\nSponsor content from Schneider Electric.\r\n"&gt;\r\nThe climate crisis is driving a global shift toward a new energy landscape, making safe and effective… [+5733 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Andrew J. Hawkins', 'title': 'The bill finally comes due for Elon Musk', 'description': 'Tesla CEO Elon Musk is finally forced to stop hiding behind his bluster and show off a real autonomous vehicle. Anything less would be a disaster.', 'url': 'https://www.theverge.com/2024/10/9/24265781/tesla-robotaxi-elon-musk-claims-safety-driverless-level-5', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/UTFYAIWx1CsXE6oKzXfSIOu2rXQ=/0x0:2040x1360/1200x628/filters:focal(1020x680:1021x681)/cdn.vox-cdn.com/uploads/chorus_asset/file/25663397/STKE001_STK086_Tesla_Robotaxi_D.jpg', 'publishedAt': '2024-10-09T14:38:07Z', 'content': 'Image: Cath Virginia / The Verge, Turbosquid\r\n\n \n\n\n The Tesla CEO has long promised — and failed to deliver —\xa0a fully autonomous vehicle. With this week’s robotaxi reveal, his time is up. For almost … [+16028 chars]'}, {'source': {'id': None, 'name': 'Yanko Design'}, 'author': 'Gaurav Sood', 'title': 'Kia reincarnates the iconic old school Pride as a powerful electric car restomod we love', 'description': 'Kia reincarnates the iconic old school Pride as a powerful electric car restomod we loveThe gas-powered Kia Pride was a successful subcompact hatchback from the 90s that was a rebatched Ford Festiva. For the 80th anniversary of the brand’s...', 'url': 'https://www.yankodesign.com/2024/10/09/kia-reincarnates-the-iconic-old-school-pride-as-a-powerful-electric-car-restomod-we-love/', 'urlToImage': 'https://www.yankodesign.com/images/design_news/2024/10/kia-reincarnates-the-old-school-pride-as-a-powerful-electric-car-restomod-we-love/Kia-Pride-EV-1.jpg', 'publishedAt': '2024-10-09T20:45:13Z', 'content': 'The gas-powered Kia Pride was a successful subcompact hatchback from the 90s that was a rebatched Ford Festiva. For the 80th anniversary of the brands business in the UK, they have restored the 1996 … [+1632 chars]'}, {'source': {'id': None, 'name': 'HYPEBEAST'}, 'author': 'info@hypebeast.com (Hypebeast)', 'title': 'Mercedes-Benz Teases First VAN.EA Prototypes', 'description': 'Mercedes-Benz has taken the next step in its electrification strategy with the unveiling of its first "VAN.EA"(Van Electric Architecture) prototypes. These prototypes represent the future of the company\'s medium and large vans, all of which will be based on t…', 'url': 'https://hypebeast.com/2024/10/mercedes-benz-van-ea-prototype-release-info', 'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2024%2F10%2F09%2Fmercedes-benz-van-ea-prototype-release-info-tw.jpg?w=1080&cbr=1&q=90&fit=max', 'publishedAt': '2024-10-09T08:13:46Z', 'content': 'Mercedes-Benz has taken the next step in its electrification strategy with the unveiling of its first “VAN.EA”(Van Electric Architecture) prototypes. These prototypes represent the future of the comp… [+1254 chars]'}, {'source': {'id': None, 'name': 'Jalopnik'}, 'author': 'Owen Bellwood', 'title': 'GM Drops Ultium EV Brand, Promises To One Day Make Money On Electric Cars', 'description': 'Good morning! It’s Wednesday, October 9, 2024, and this is The Morning Shift, your daily roundup of t ...

# %%
data = pd.DataFrame.from_dict(articles, orient='columns')

len(data)
# Out:
# 500

# %%
data = pd.concat([data, previous]).reset_index(drop=True)

# %%
data[data['title']!="[Removed]"].to_csv('/Users/ruinah/Downloads/llm_prompting/data/tech_news_articles2.csv', index=False)

# %%
# data.to_csv('/Users/ruinah/Downloads/llm_prompting/tech_news_articles.csv')

# %%
# data.to_csv('/Users/ruinah/Downloads/llm_prompting/tech_news_articles.csv')
